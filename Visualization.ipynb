# %% [markdown]
# Matplotlib: low level,provides lots of freedom....Pandas Visulaization...seaborn..ggplot

# %% [markdown]
# Best Practices of Data Visualization-

# %% [markdown]
# 1. Know your audience
# 2. Choose right data visualization (Plotting techniques)
# 3. Readability of Visualization
# 4. Add a legend to visualization

# %% [markdown]
# Types of data visualization-
# 1. exploratory visualization helps us understand the data
# 2. explanatory visualization used to share the data to others

# %% [markdown]
# EDA(Exploratory Data Analysis)

# %% [markdown]
# Process-1
# 1. Examine the data distribution
# 2.  Identify the outliers
# 3. Remove the outliers
# 4. Check the normality of the data
# 5. Perform the t-test
# 6. Interpret the results
# 7. Draw conclusions
# 8. Report the results

# %% [markdown]
# Tools-
# 1. Tableau,QlikView,FushionCharts,etc
# 2. Popular are matplotlib,pyplot

# %% [markdown]
# Matplotlib- scatterplot,etc

# %% [markdown]
# Matplotlib has a module called pyplot which aids in plotting figure.
# import matplotlib.pyplot as plt or from matplotlib import pyplot as plt
# plt.plot()

# %% [markdown]
# plt.xlabel and plt.ylabel for labelling for x and y-axis

# %% [markdown]
# Linestyle

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle=':')
plt.show()

# %% [markdown]
# COLOR

# %% [markdown]
# RGB-red green blue

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,c='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,c='yellow')
plt.show()

# %% [markdown]
# Linewidth

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linewidth='15')
plt.show()

# %% [markdown]
# 2 Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([3,8,1,10])
y2=np.array([6,2,8,1])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([31,8,19,10,7,24,9,17,45,28,89])
y2=np.array([62,21,83,13,59,8,12,16,94,42,29])

plt.scatter(y1,y2)

plt.show()

# %% [markdown]
# 2plots

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([31,8,19,10,7,24,9,17,45,28,89])
y2=np.array([62,21,83,13,59,8,12,16,94,42,29])

plt.scatter(y1,y2)

y1=np.array([33,56,89,23,45,70,65,12,34,98,56])
y2=np.array([45,67,87,23,45,32,12,67,83,92,40])

plt.scatter(y1,y2)

plt.show()

# %% [markdown]
# Bar Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.bar(y1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.barh(y1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.bar(y1,y2,color="pink")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.bar(y1,y2,width=0.1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.barh(y1,y2,height=0.1)

plt.show()

# %% [markdown]
# Histogram

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [168.45746908 192.07001878 167.19223981 162.54717502 176.91032029
#  177.15997389 174.33412478 160.88877142 177.73145734 176.08544861
#  167.68114968 165.32016756 176.09405265 156.85251369 156.638627
#  168.99287925 170.78923427 149.93326494 163.97526623 186.88764471
#  172.58803522 168.48085436 167.89364394 175.72391505 168.13480938
#  168.19323646 179.5906138  162.6201225  169.89354693 177.21911079
#  188.21640969 160.7572365  176.32287477 161.95198012 176.29422687
#  177.79683808 176.89951509 170.88127294 177.45091756 183.92503021
#  161.19373124 172.71838022 161.40156134 181.03202206 177.37852325
#  180.51819541 163.72781843 174.459084   162.301376   157.22688606
#  158.77989888 164.2278234  165.90820913 159.58090658 175.82720743
#  150.66897186 177.10561559 172.67255659 169.60236939 169.09253226
#  178.75201065 171.98931714 171.35894902 172.04774433 171.25758572
#  174.68868953 175.92451054 193.26056028 162.38140432 162.02663469
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# Pi Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Labels

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# Start Angle

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# Explode

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Shadow

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# Colors

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# Legend With Header

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# Autopct function to write the percent

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,  autopct="%1.1f%%")
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,  autopct="%1.2f%%")
plt.show()

# %% [markdown]
# Lollipop

# %% [markdown]
# Its a bar plot where bar is transformed in a line and a dot.It compares the different classes of a category.stem() functionnis used to create these charts.

# %% [markdown]
# Arguments
# 1. Maker format- markerfmt='s'
# 2. Line format- linefmat='-'
# 3. Baseline FOrmat- basefmt= ':'

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(np.log(0.2*np.pi)),10)

plt.stem(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(0.2*2),10)

plt.stem(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(np.log(0.2*np.pi)),10)

plt.stem(x,y,markerfmt='d',linefmt='--',basefmt=':')
plt.show()

# %% [markdown]
# Area Charts

# %%
import pandas as pd
data={'Year':[2015,2016,2017,2018,2019],'Sales':[100,150,200,180,250]}

df=pd.DataFrame(data)
df.head()
# Out:
#    Year  Sales
# 0  2015    100
# 1  2016    150
# 2  2017    200
# 3  2018    180
# 4  2019    250

# %%
#pip install plotly

# %%
pip install nbformat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
fig=px.area(df,x='Year',y='Sales')
fig.show()

# %%
fig.update_traces(fillcolor='pink')
fig.show()

# %%
fig.update_traces(line=dict(color='red',width=5))
fig.show()

# %% [markdown]
# Stacked Area Chart

# %%
import pandas as pd

import plotly.express as px

data=pd.DataFrame({"Values":[2015,2016,2017,2018,2019],'Category A':[10,20,30,40,50],'Category B':[20,30,40,24,34],'Category C':[50,60,30,20,40]})

#Create a stacked area chart

fig=px.area(data,x="Values",y=["Category A","Category B","Category C"],title="Stacked Area Chart")

fig.show()

# %% [markdown]
# Box Plot

# %% [markdown]
# Box Plot gives summary of one or several numeric variables.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
data=np.random.normal(100,20,200)

fig=plt.figure(figsize=(10,7))

plt.boxplot(data)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Creating dataset
np.random.seed(10)
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(90, 20, 200)
data3 = np.random.normal(80, 30, 200)
data4 = np.random.normal(70, 40, 200)

# Group all data together in a list
data = [data1, data2, data3, data4]

# Creating figure and axes
fig = plt.figure(figsize=(10, 7))
ax = fig.add_axes([0, 0, 1, 1])

# Creating boxplot
bp = ax.boxplot(data, labels=["Data1", "Data2", "Data3", "Data4"])

# Show plot
plt.title("Boxplot of Multiple Datasets")
plt.ylabel("Values")
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_9964\2032357490.py:19: MatplotlibDeprecationWarning:
#
# The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.

# %% [markdown]
# Violin Plots

# %% [markdown]
# Combination of histogram and box plot

# %%
import numpy as np
import matplotlib.pyplot as plt

#Generate random data
np.random.seed(1)
data = np.random.randn(100)

#Create a voilin plot
plt.figure()
plt.violinplot(data, showmedians=True)

#Set plot labels and title
plt.xlabel('Variable')
plt.ylabel('Value')
plt.title('Univariate Violin Plot')

#SHow plot
plt.show()

# %% [markdown]
# HeatMaps

# %% [markdown]
# seaborn.heatmap(data,vmin=None,vmax=None,cmap=None,center=None,annot_kws=None,linewidths=0,linecolor="white",cbar=True)

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

#generating 2-D 10*10 matrix of random numbers
# from 1 to 100

data=np.random.randint(low=1,high=100,size=(10,10))

print("The data to be plotted: \n",data)

#plotting the heatmap

hm=sn.heatmap(data=data)

#displaying the plotted heatmap
plt.show()
# Out:
# The data to be plotted:
#  [[34  3 85 84 49 55 33 29 56 83]
#  [32 29 95 75  9 33  9 85 78 51]
#  [80 42 65 84 25 21 45 16 31 92]
#  [15 20 27 87  8 54 48 61 35 33]
#  [20 68 25 84 95 39 48  6 80 64]
#  [88 33 43 75 67 89 99 31 18 69]
#  [65 61 79 18 40 36 82 29 23 39]
#  [42 75 78 71 26 49 51 63 45 55]
#  [ 1 87 17 20 10 93 52 11 69 24]
#  [15 64 22 47  4 57 89 81 47 55]]

# %% [markdown]
# setting the parameter values

# %%
hm=sn.heatmap(data=data,vmin=30,vmax=70)
plt.show()

# %%
hm=sn.heatmap(data=data,cmap="tab20")
plt.show()

# %%
hm=sn.heatmap(data=data,cmap="coolwarm")
plt.show()

# %% [markdown]
# Displaying the Cell Values

# %%
hm=sn.heatmap(data=data,annot=True)
plt.show()

# %%
hm=sn.heatmap(data=data,annot=False)
plt.show()

# %% [markdown]
# Customizing the size of line

# %%
hm=sn.heatmap(data=data,annot=True,linewidths=3,linecolor="black")
plt.show()

# %% [markdown]
# Hiding color bar

# %%
hm=sn.heatmap(data=data,annot=True,cbar=False)
plt.show()

# %%
hm=sn.heatmap(data=data,annot=True,cbar=True)
plt.show()

# %% [markdown]
# Wordcloud

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re

df = pd.read_csv("IMDB Dataset.csv")
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
# 1. Define stopwords set
stopwords = set(STOPWORDS)

# 2. Define text cleaning function
def clean_text(text):
    text = re.sub(r'[^A-Za-z\s]', '', str(text))  # keep only letters and spaces
    text = text.lower()  # convert to lowercase
    text = ' '.join(word for word in text.split() if word not in stopwords)  # remove stopwords
    return text

# 3. Apply cleaning on all reviews
df['cleaned_review'] = df['review'].apply(clean_text)

# 4. Join all cleaned reviews into one string
all_text = ' '.join(df['cleaned_review'].tolist())

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=1600, height=800, background_color='white').generate(all_text)

plt.figure(figsize=(16, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("WordCloud of Reviews", fontsize=20)
plt.show()
