# %% [markdown]
# Matplotlib: low level,provides lots of freedom....Pandas Visulaization...seaborn..ggplot

# %% [markdown]
# Best Practices of Data Visualization-

# %% [markdown]
# 1. Know your audience
# 2. Choose right data visualization (Plotting techniques)
# 3. Readability of Visualization
# 4. Add a legend to visualization

# %% [markdown]
# Types of data visualization-
# 1. exploratory visualization helps us understand the data
# 2. explanatory visualization used to share the data to others

# %% [markdown]
# EDA(Exploratory Data Analysis)

# %% [markdown]
# Process-1
# 1. Examine the data distribution
# 2.  Identify the outliers
# 3. Remove the outliers
# 4. Check the normality of the data
# 5. Perform the t-test
# 6. Interpret the results
# 7. Draw conclusions
# 8. Report the results

# %% [markdown]
# Tools-
# 1. Tableau,QlikView,FushionCharts,etc
# 2. Popular are matplotlib,pyplot

# %% [markdown]
# Matplotlib- scatterplot,etc

# %% [markdown]
# Matplotlib has a module called pyplot which aids in plotting figure.
# import matplotlib.pyplot as plt or from matplotlib import pyplot as plt
# plt.plot()

# %% [markdown]
# plt.xlabel and plt.ylabel for labelling for x and y-axis

# %% [markdown]
# Linestyle

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\cheta\python\venv\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cheta\python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\cheta\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linestyle=':')
plt.show()

# %% [markdown]
# COLOR

# %% [markdown]
# RGB-red green blue

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,c='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,c='yellow')
plt.show()

# %% [markdown]
# Linewidth

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,1,10])

plt.plot(ypoints,linewidth='15')
plt.show()

# %% [markdown]
# 2 Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([3,8,1,10])
y2=np.array([6,2,8,1])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([31,8,19,10,7,24,9,17,45,28,89])
y2=np.array([62,21,83,13,59,8,12,16,94,42,29])

plt.scatter(y1,y2)

plt.show()

# %% [markdown]
# 2plots

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([31,8,19,10,7,24,9,17,45,28,89])
y2=np.array([62,21,83,13,59,8,12,16,94,42,29])

plt.scatter(y1,y2)

y1=np.array([33,56,89,23,45,70,65,12,34,98,56])
y2=np.array([45,67,87,23,45,32,12,67,83,92,40])

plt.scatter(y1,y2)

plt.show()

# %% [markdown]
# Bar Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.bar(y1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1=np.array([1,2,3,4,5,6])
y2=np.array([6,2,8,1,5,10])

plt.barh(y1,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#  167.85168417 167.97118797 170.63589618 169.64663235 174.26955301
#  173.21661833 172.29483275 179.07186827 168.45039946 169.73781804
#  182.3360976  166.66635292 184.67287952 184.31001434 147.78059618
#  164.28455719 165.71548095 166.50930051 162.92259964 159.19719494
#  181.33861546 172.82665144 163.62494362 160.15546462 169.28149918
#  176.91296849 168.24480124 162.87499647 158.29023909 164.29766811
#  165.31925507 172.56008331 168.35454203 184.0825622  169.11734977
#  173.38684071 167.1700394  174.88787151 183.31164001 171.8778512
#  168.55183552 171.74358185 184.20678973 166.39354004 166.56761979
#  156.06866662 180.92460496 179.35613448 162.66326101 174.17039778
#  180.11376782 168.81102782 180.04061376 158.31210616 151.45190683
#  196.67017907 178.22012212 182.12347945 152.13536966 158.45742329]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# Pi Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Labels

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# Start Angle

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# Explode

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Shadow

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# Colors

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# Legend

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# Legend With Header

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# Autopct function to write the percent

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,  autopct="%1.1f%%")
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels,  autopct="%1.2f%%")
plt.show()

# %% [markdown]
# Lollipop

# %% [markdown]
# Its a bar plot where bar is transformed in a line and a dot.It compares the different classes of a category.stem() functionnis used to create these charts.

# %% [markdown]
# Arguments
# 1. Maker format- markerfmt='s'
# 2. Line format- linefmat='-'
# 3. Baseline FOrmat- basefmt= ':'

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(np.log(0.2*np.pi)),10)

plt.stem(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(0.2*2),10)

plt.stem(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=['A','B','C','D','E','F','G','H','I','J']
y=np.linspace(1,(np.log(0.2*np.pi)),10)

plt.stem(x,y,markerfmt='d',linefmt='--',basefmt=':')
plt.show()

# %% [markdown]
# Area Charts

# %%
import pandas as pd
data={'Year':[2015,2016,2017,2018,2019],'Sales':[100,150,200,180,250]}

df=pd.DataFrame(data)
df.head()
# Out:
#    Year  Sales
# 0  2015    100
# 1  2016    150
# 2  2017    200
# 3  2018    180
# 4  2019    250

# %%
#pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-1.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\cheta\python\venv\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/14.8 MB 10.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/14.8 MB 9.8 MB/s eta 0:00:02
#    -------------- ------------------------- 5.2/14.8 MB 8.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/14.8 MB 7.6 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.8 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.2/14.8 MB 7.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.7/14.8 MB 7.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.8 MB 7.5 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.8 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 7.6 MB/s eta 0:00:00
# Downloading narwhals-1.29.1-py3-none-any.whl (308 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-1.29.1 plotly-6.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nbformat
# Out:
# Collecting nbformat
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\cheta\python\venv\lib\site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in c:\users\cheta\python\venv\lib\site-packages (from nbformat) (5.14.3)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.23.1-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\cheta\python\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\cheta\python\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (308)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\cheta\python\venv\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.12.2)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.23.1-cp311-cp311-win_amd64.whl (232 kB)
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-25.1.0 fastjsonschema-2.21.1 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 nbformat-5.10.4 referencing-0.36.2 rpds-py-0.23.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
fig=px.area(df,x='Year',y='Sales')
fig.show()

# %%
fig.update_traces(fillcolor='pink')
fig.show()

# %%
fig.update_traces(line=dict(color='red',width=5))
fig.show()

# %% [markdown]
# Stacked Area Chart

# %%
import pandas as pd

import plotly.express as px

data=pd.DataFrame({"Values":[2015,2016,2017,2018,2019],'Category A':[10,20,30,40,50],'Category B':[20,30,40,24,34],'Category C':[50,60,30,20,40]})

#Create a stacked area chart

fig=px.area(data,x="Values",y=["Category A","Category B","Category C"],title="Stacked Area Chart")

fig.show()

# %% [markdown]
# Box Plot

# %% [markdown]
# Box Plot gives summary of one or several numeric variables.

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
data=np.random.normal(100,20,200)

fig=plt.figure(figsize=(10,7))

plt.boxplot(data)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Creating dataset
np.random.seed(10)
data1 = np.random.normal(100, 10, 200)
data2 = np.random.normal(90, 20, 200)
data3 = np.random.normal(80, 30, 200)
data4 = np.random.normal(70, 40, 200)

# Group all data together in a list
data = [data1, data2, data3, data4]

# Creating figure and axes
fig = plt.figure(figsize=(10, 7))
ax = fig.add_axes([0, 0, 1, 1])

# Creating boxplot
bp = ax.boxplot(data, labels=["Data1", "Data2", "Data3", "Data4"])

# Show plot
plt.title("Boxplot of Multiple Datasets")
plt.ylabel("Values")
plt.show()
# Out:
# C:\Users\cheta\AppData\Local\Temp\ipykernel_16188\2032357490.py:19: MatplotlibDeprecationWarning:
#
# The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.

# %% [markdown]
# Violin Plots

# %% [markdown]
# Combination of histogram and box plot

# %%
import numpy as np
import matplotlib.pyplot as plt

#Generate random data
np.random.seed(1)
data = np.random.randn(100)

#Create a voilin plot
plt.figure()
plt.violinplot(data, showmedians=True)

#Set plot labels and title
plt.xlabel('Variable')
plt.ylabel('Value')
plt.title('Univariate Violin Plot')

#SHow plot
plt.show()
